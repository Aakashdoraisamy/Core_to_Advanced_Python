# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ## groupby which is used to group by non aggregated columns
# ## based on group by we can perform aggregation functions ex: min,max,mean,sum

# %%
groups_values = df.groupby('gender')

# %%
groups_values

# %%
res = groups_values.groups # groups is a varaiable which returns dictionary and it keeps values as unique values

# %%
res.keys()
# Out:
# dict_keys(['female', 'male'])

# %%
res['female']
# Out:
# Index([  0,   1,   2,   5,   6,   9,  12,  14,  15,  17,
#        ...
#        986, 988, 989, 991, 992, 993, 995, 997, 998, 999],
#       dtype='int64', length=518)

# %%
res['male']
# Out:
# Index([  3,   4,   7,   8,  10,  11,  13,  16,  18,  20,
#        ...
#        976, 977, 978, 981, 982, 985, 987, 990, 994, 996],
#       dtype='int64', length=482)

# %% [markdown]
# ## dataframe.get_group()

# %% [markdown]
# ## get_groups is used to extract particular grouped records
# ### it is case sensitive

# %%
groups_values.get_group('female')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ## male ------|group A |
# ##            |group B | --- count
# ##            |group C |
#
# ## female ------|group A |
# ##              |group B | --- count
# ##              |group C |

# %%
grouped_column = df.groupby('gender')

# %%
male = grouped_column.get_group('male')
female = grouped_column.get_group('female')

# %%
male['race/ethnicity'].value_counts(ascending=True)
# Out:
# race/ethnicity
# group A     53
# group E     71
# group B     86
# group D    133
# group C    139
# Name: count, dtype: int64

# %%
female['race/ethnicity'].value_counts(ascending=True)
# Out:
# race/ethnicity
# group A     36
# group E     69
# group B    104
# group D    129
# group C    180
# Name: count, dtype: int64

# %%
df.groupby('gender')['race/ethnicity'].value_counts(ascending=True)
# Out:
# gender  race/ethnicity
# female  group A            36
#         group E            69
#         group B           104
#         group D           129
#         group C           180
# male    group A            53
#         group E            71
#         group B            86
#         group D           133
#         group C           139
# Name: count, dtype: int64

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
g_c = df.groupby('gender')['writing score'].mean()
g_c
# Out:
# gender
# female    72.467181
# male      63.311203
# Name: writing score, dtype: float64

# %% [markdown]
# ## get the group A along with associate degree of male

# %%
df['gender'] = 'male'
df
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group B           bachelor's degree      standard
# 1     male        group C                some college      standard
# 2     male        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# ..     ...            ...                         ...           ...
# 995   male        group E             master's degree      standard
# 996   male        group C                 high school  free/reduced
# 997   male        group C                 high school  free/reduced
# 998   male        group D                some college      standard
# 999   male        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
df.query('(gender == "male") & (`race/ethnicity` == "group A") & (`parental level of education` == "associate\'s degree")')
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 62    male        group A          associate's degree  free/reduced
# 112   male        group A          associate's degree      standard
# 356   male        group A          associate's degree      standard
# 489   male        group A          associate's degree  free/reduced
# 539   male        group A          associate's degree      standard
# 575   male        group A          associate's degree  free/reduced
# 936   male        group A          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# 62                     none          62             61             55
# 112                    none          54             53             47
# 356                    none          63             61             61
# ...

# %%
df[(df['gender'] == 'male') & (df['race/ethnicity'] == "group A") & (df['parental level of education'] == "associate's degree")]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 62    male        group A          associate's degree  free/reduced
# 112   male        group A          associate's degree      standard
# 356   male        group A          associate's degree      standard
# 489   male        group A          associate's degree  free/reduced
# 539   male        group A          associate's degree      standard
# 575   male        group A          associate's degree  free/reduced
# 936   male        group A          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# 62                     none          62             61             55
# 112                    none          54             53             47
# 356                    none          63             61             61
# ...

# %%
gv = groups.groupby(['gender','race/ethnicity','parental level of education'])
gv.get_group(('male','group A','associate\'s degree'))

# %% [markdown]
# ## reset_index()

# %%
filter = df.groupby('gender').get_group('male')
filter.reset_index(inplace=True)

# %%
filter
# Out:
#      index gender race/ethnicity parental level of education         lunch  \
# 0        3   male        group A          associate's degree  free/reduced
# 1        4   male        group C                some college      standard
# 2        7   male        group B                some college  free/reduced
# 3        8   male        group D                 high school  free/reduced
# 4       10   male        group C          associate's degree      standard
# ..     ...    ...            ...                         ...           ...
# 477    985   male        group A                 high school      standard
# 478    987   male        group E            some high school      standard
# 479    990   male        group E                 high school  free/reduced
# 480    994   male        group A                 high school      standard
# 481    996   male        group C                 high school  free/reduced
#
# ...

# %%
filter.drop(['index'],axis=1) # here inplace=True doesn't return table
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group A          associate's degree  free/reduced
# 1     male        group C                some college      standard
# 2     male        group B                some college  free/reduced
# 3     male        group D                 high school  free/reduced
# 4     male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 477   male        group A                 high school      standard
# 478   male        group E            some high school      standard
# 479   male        group E                 high school  free/reduced
# 480   male        group A                 high school      standard
# 481   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          47             57             44
# ...

# %%
filter = df.groupby('gender').get_group('male')
filter.reset_index(inplace=True,drop=True) # drop = True removes the index if it is false it keeps

# %%
filter.head(10)
# Out:
#   gender race/ethnicity parental level of education         lunch  \
# 0   male        group A          associate's degree  free/reduced
# 1   male        group C                some college      standard
# 2   male        group B                some college  free/reduced
# 3   male        group D                 high school  free/reduced
# 4   male        group C          associate's degree      standard
# 5   male        group D          associate's degree      standard
# 6   male        group A                some college      standard
# 7   male        group C                 high school      standard
# 8   male        group C             master's degree  free/reduced
# 9   male        group D                 high school      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          47             57             44
# 1                    none          76             78             75
# ...

# %%
df1 = pd.DataFrame({'SRH':['Abhishek Sharma','Travis Head','Pat Cummins','Henrich Klassen','Ishan Kishan'],
                   'CSK':['MS Dhoni','Albie Morkel','Suresh Raina','Ravindra Jadeja','DJ Bravo']})
df1
# Out:
#                SRH              CSK
# 0  Abhishek Sharma         MS Dhoni
# 1      Travis Head     Albie Morkel
# 2      Pat Cummins     Suresh Raina
# 3  Henrich Klassen  Ravindra Jadeja
# 4     Ishan Kishan         DJ Bravo

# %%
df2 = pd.DataFrame({'SRH':['David Warner','Kane Williamson','Bhuvenshwar Kumar','Rashid Khan','Shikwar Dhawan'],
                   'HDC':['Adam Gilchrist','Andrew Simons','Rohit Sharma','RP Singh','H Gibbs']})
df2
# Out:
#                  SRH             HDC
# 0       David Warner  Adam Gilchrist
# 1    Kane Williamson   Andrew Simons
# 2  Bhuvenshwar Kumar    Rohit Sharma
# 3        Rashid Khan        RP Singh
# 4     Shikwar Dhawan         H Gibbs

# %%
df3 = pd.DataFrame({'SRH':['David Warner','Kane Williamson','Bhuvenshwar Kumar','Rashid Khan','Shikwar Dhawan'],
                   'MI':['Rohit Sharma','Lasit Malinga','Kieren Pollard','Hardik Pandya','Jasprit Bumra']})
df3
# Out:
#                  SRH              MI
# 0       David Warner    Rohit Sharma
# 1    Kane Williamson   Lasit Malinga
# 2  Bhuvenshwar Kumar  Kieren Pollard
# 3        Rashid Khan   Hardik Pandya
# 4     Shikwar Dhawan   Jasprit Bumra

# %%
pd.concat([df1,df2]) # by default axis = 0 so it adds row wise means downwards
# Out:
#                  SRH              CSK             HDC
# 0    Abhishek Sharma         MS Dhoni             NaN
# 1        Travis Head     Albie Morkel             NaN
# 2        Pat Cummins     Suresh Raina             NaN
# 3    Henrich Klassen  Ravindra Jadeja             NaN
# 4       Ishan Kishan         DJ Bravo             NaN
# 0       David Warner              NaN  Adam Gilchrist
# 1    Kane Williamson              NaN   Andrew Simons
# 2  Bhuvenshwar Kumar              NaN    Rohit Sharma
# 3        Rashid Khan              NaN        RP Singh
# 4     Shikwar Dhawan              NaN         H Gibbs

# %%
pd.concat([df1,df3],join='inner',axis=0,ignore_index=True) # works with only axis = 0
# Out:
#                  SRH
# 0    Abhishek Sharma
# 1        Travis Head
# 2        Pat Cummins
# 3    Henrich Klassen
# 4       Ishan Kishan
# 5       David Warner
# 6    Kane Williamson
# 7  Bhuvenshwar Kumar
# 8        Rashid Khan
# 9     Shikwar Dhawan

# %%
pd.concat([df1,df3],join='inner',axis=1)
# Out:
#                SRH              CSK                SRH              MI
# 0  Abhishek Sharma         MS Dhoni       David Warner    Rohit Sharma
# 1      Travis Head     Albie Morkel    Kane Williamson   Lasit Malinga
# 2      Pat Cummins     Suresh Raina  Bhuvenshwar Kumar  Kieren Pollard
# 3  Henrich Klassen  Ravindra Jadeja        Rashid Khan   Hardik Pandya
# 4     Ishan Kishan         DJ Bravo     Shikwar Dhawan   Jasprit Bumra

# %%
male = df.groupby('gender').get_group('male')
female = df.groupby('gender').get_group('female')

# %%
new_df = pd.concat([male,female],keys = ['male','female'])
# new_df.index
new_df
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# male   3      male        group A          associate's degree  free/reduced
#        4      male        group C                some college      standard
#        7      male        group B                some college  free/reduced
#        8      male        group D                 high school  free/reduced
#        10     male        group C          associate's degree      standard
# ...            ...            ...                         ...           ...
# female 993  female        group D           bachelor's degree  free/reduced
#        995  female        group E             master's degree      standard
#        997  female        group C                 high school  free/reduced
#        998  female        group D                some college      standard
#        999  female        group D                some college  free/reduced
#
# ...
